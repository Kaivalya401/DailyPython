# %%
print("Welcome to simple Python Quiz")
play =input("Do you wanna Play a Game? ").lower()

if play !='yes':
    quit()
else:
    print("Let's get started!")

score = 0

q1 = print("QUESTION :1  What is the output of evaluating bool('False') in Python?")
print("""option1: None  
option2: Value Error 
option3: False
option4: True""")
q1_ans = int(input("Type your option number (example:2) :"))
if q1_ans != 4:
    print("wrong answer")
else:
    print("You got it")
    score +=1
print(""" 
""")
q2 = print("QUESTION:2 Given the code a = [1, 2, 3]; b = a; b += [4], what is the resulting value of a?")
print("""option1: [4]
option2: [1,2,3[4]]
option3: [1,2,3]
option4: [1,2,3,4] """)
q2_ans = int(input("Type your option number : "))
if q2_ans != 4:
    print("wrong answer")
else:
    print("You got it")
    score +=1
print(""" 
""")
q3 = print(" QUESTION:3  Which of the following data types can be used as a valid dictionary key in Python?")
print("""option1: ['user_id']
option2: ('user_id',1)
option3: {'user_id'}
option4: {'user_id':1} """)
q3_ans = int(input("Type your option number : "))
if q3_ans != 2:
    print("wrong answer")
else:
    print("You got it")
    score +=1
print(""" 
""")
q4 = print("QUESTION:4 What happens when executing the slice operation 'Python'[-2:-5:-1]?")
print("""option1: 'nothy' 
option2: 'hto'
option3: 'ohty'
option4: 'oht' """)
q4_ans = int(input("Type your option number : "))
if q4_ans != 4:
    print("wrong answer")
else:
    print("You got it")
    score +=1
print(""" 
""")
q5 = print("QUESTION:5  What is printed by calling f() twice for the function def f(val, items=[]): items.append(val); return items with arguments f(1) then f(2)?")
print("""option1 : [1] then [1,2]
option2: Type Error
option3: [1] then [[1],2]
option4: [1] then [2] """)
q5_ans = int(input("Type your option number : "))
if q5_ans != 1:
    print("wrong answer")
else:
    print("You got it")
    score +=1

print(f"YOUR FINAL SCORE :{round((score/5)*100)}%")
# Out:
# Welcome to simple Python Quiz
# Do you wanna Play a Game?  Yes
# Let's get started!
# QUESTION :1  What is the output of evaluating bool('False') in Python?
# option1: None
# option2: Value Error
# option3: False
# option4: 4
# True
# Type your option number (example:2) : 4
# u got it
#
#
# QUESTION:2 Given the code a = [1, 2, 3]; b = a; b += [4], what is the resulting value of a?
# option1: [4]
# option2: [1,2,3[4]]
# option3: [1,2,3]
# option4: [1,2,3,4]
# Type your option number :  4
# You git it
#
#
#  QUESTION:3  Which of the following data types can be used as a valid dictionary key in Python?
# option1: ['user_id']
# option2: ('user_id',1)
# option3: {'user_id'}
# option4: {'user_id':1}
# Type your option number :  2
# you got it
#
#
# QUESTION:4 What happens when executing the slice operation 'Python'[-2:-5:-1]?
# option1: 'nothy'
# option2: 'hto'
# option3: 'ohty'
# option4: 'oht'
# Type your option number :  4
# You got it
#
#
# ...
